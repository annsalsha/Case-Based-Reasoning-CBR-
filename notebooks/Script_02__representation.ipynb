# %%
import re

def nomor_perkara(text):
    # Cari pola nomor perkara, tetap fleksibel terhadap spasi
    match = re.search(
        r'\d+\s*/\s*pid\.sus-tpk\s*/\s*\d+\s*/\s*pn\s+sby',
        text,
        flags=re.IGNORECASE
    )

    if match:
        return match.group()  # Jangan hapus spasi, biar tetap 'pn sby'
    else:
        return None

# %%
import re

def amar_putusan(text):
    # Normalisasi angka dan spasi
    text = re.sub(r"(\d+)\.(\S)", r"\1. \2", text)
    text = re.sub(r";\s*(\d+)\.", r"; \1.", text)

    # Toleransi spasi antar huruf 'mengadili'
    pattern_mengadili = re.compile(r"m\s*e\s*n\s*g\s*a\s*d\s*i\s*l\s*i", flags=re.IGNORECASE)
    matches = list(pattern_mengadili.finditer(text))
    if not matches:
        return ""

    last_match = matches[-1]
    amar_text = text[last_match.end():].strip()

    # Ambil isi dari 1. sampai sebelum ; 5.
    match = re.search(r"1\.\s*(.*?)(?=;\s*5\.)", amar_text, flags=re.DOTALL)
    if not match:
        return ""

    combined_text = match.group(1)

    # Pisahkan jadi 4 poin berdasarkan ; 2., ; 3., ; 4.
    split_points = re.split(r";\s*2\.\s*|\s*;\s*3\.\s*|\s*;\s*4\.\s*", combined_text)

    # Ambil maksimal 4 poin dan bersihkan
    cleaned = []
    for p in split_points[:4]:
        sentence = re.sub(r'\s+', ' ', p.strip())
        # Tambahkan titik jika belum ada di akhir
        if not sentence.endswith('.'):
            sentence += '.'
        cleaned.append(sentence)

    # Gabungkan dengan transisi
    if len(cleaned) == 4:
        return f"{cleaned[0]} Selain itu, {cleaned[1]} Selanjutnya, {cleaned[2]} Terakhir, {cleaned[3]}"
    else:
        return ' '.join(cleaned)

# %%
import re

def extract_barang_bukti(text):
    # Deteksi kata 'mengadili' dengan toleransi spasi
    pattern_mengadili = re.compile(r"m\s*e\s*n\s*g\s*a\s*d\s*i\s*l\s*i\s*:?", flags=re.IGNORECASE)
    matches = list(pattern_mengadili.finditer(text))
    if not matches:
        return ""

    # Ambil teks setelah 'mengadili'
    last_match = matches[-1]
    amar_text = text[last_match.end():].strip()

    # Cari frasa 'barang bukti berupa'
    bb_header = re.search(
        r"(menetapkan\s+)?barang\s+bukti\s+berupa\s*:?", amar_text, flags=re.IGNORECASE
    )
    if not bb_header:
        return ""

    # Ambil teks setelah bagian header barang bukti
    bb_text = amar_text[bb_header.end():].strip()

    # Potong sebelum poin selanjutnya yang diawali angka + kata kerja hukum
    stop_match = re.search(
        r"\d+\.\s*(menetapkan|membebankan|memerintahkan|memulihkan|menyatakan)",
        bb_text, flags=re.IGNORECASE | re.MULTILINE
    )
    if stop_match:
        bb_text = bb_text[:stop_match.start()].strip()

    # Ambil poin-poin barang bukti
    items = re.findall(r"(?:\d+[\.\)])\s*(.*?)(?=\n\s*\d+[\.\)]|\Z)", bb_text, flags=re.DOTALL)

    if not items:
        return ""

    # Bersihkan
    cleaned = [re.sub(r'\s+', ' ', item.strip()) for item in items]
    joined = ' dan '.join(cleaned)

    return f"Barang bukti berupa {joined}." if joined else ""

# %%
import re

def extract_pekerjaan(text):
    # 1. Bagi berdasarkan terdakwa: pakai romawi diikuti angka dan titik (misalnya: i.1., ii.1., dst)
    # Asumsikan bagian terdakwa diakhiri sebelum "mengadili" atau "menimbang" atau teks utama dimulai
    parts = re.split(r"(?=\b(?:i{1,3}|iv|v|vi|vii|viii|ix|x)[.]\s*1[.])", text, flags=re.IGNORECASE)

    pekerjaan_list = []

    for part in parts:
        # 2. Cari 'pekerjaan' di setiap bagian
        match = re.search(
            r"(?i)pekerjaan\s*:?\s*(.+?)(?=\s*(?:agama|pendidikan|terdakwa|status|[0-9]{1,2}[.)])\b|[;\n\.]|$)",
            part
        )
        if match:
            pekerjaan = re.sub(r'\s+', ' ', re.sub(r',+', '', match.group(1))).strip()
            pekerjaan_list.append(pekerjaan)

    return pekerjaan_list

# %%
import re

def extract_penuntut_umum(text):
    # Tangani jika HANYA ada Penuntut Umum TANPA nama
    pattern_tanpa_nama = r"(?:dengan|serta)[\s]*dihadiri[\s]*oleh[\s]*(?:Jaksa[\s]*Penuntut[\s]*Umum|Penuntut[\s]*Umum|JaksaPenuntutUmum|PenuntutUmum)(?![\w])"
    if re.search(pattern_tanpa_nama, text, re.IGNORECASE | re.DOTALL):
        return "tidak disebutkan"

    # Tangani jika nama disebutkan sebelum frasa penuntut umum
    pattern_nama = r"(?:dengan|serta)[\s]*dihadiri[\s]*oleh[\s]*([\w\s.,()-]+?)\s*(?:selaku|sebagai)?\s*(?:Jaksa[\s]*Penuntut[\s]*Umum|Penuntut[\s]*Umum|JaksaPenuntutUmum|PenuntutUmum)"
    match = re.search(pattern_nama, text, re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()

    return "tidak ada informasi"

# %%
import re

def nama_terdakwa(text):
    pattern = r"(?i)(?:\d\.\s*)?(?:nama lengkap|nama)\s*:?\s*([\s\S]{3,100}?)(?=\s*(?:\d?[.)]?\s*)?tempat\s+lahir)"
    return [m.strip() for m in re.findall(pattern, text)]

# %%
import re

def extract_metadata(text):
    data = {}

    # Nomor perkara
    data['nomor_perkara'] = nomor_perkara(text)

    # m = re.findall(r"nama lengkap\s*:?\s*([a-zA-Z.,\-\s]+)", text, flags=re.IGNORECASE)
    data['nama_terdakwa'] = nama_terdakwa(text)

    # Pekerjaan
    data['pekerjaan'] = extract_pekerjaan(text)

    # perkara
    m = re.search(r"tindak pidana\s*:?\s*([a-z\s\-\,]+)", text)
    data['tindak pidana'] = m.group(1).strip().split()[0] if m else ""

    # Pasal
    m = re.search(r"Pasal\s+[^\n]*?Tahun\s+\d{4}", text, flags=re.IGNORECASE)
    data['pasal'] = m.group(0).strip() if m else ""

    # penuntut umum / penggugat
    data['penuntut_umum'] = extract_penuntut_umum(text)

    # Tanggal (optional)
    m = re.search(r"(diputuskan|putusan)[^\n]*tanggal\s+(\d{1,2}\s+[A-Za-z]+\s+\d{4})", text, flags=re.IGNORECASE)
    data['tanggal_putusan'] = m.group(2).strip() if m else ""

    # penuntut umum / penggugat
    data['amar_putusan'] = amar_putusan(text)

    # penuntut umum / penggugat
    data['ringkasan_barang_bukti'] = extract_barang_bukti(text)

    return data

# %%
import pandas as pd
import os

# Misal nama file yang mau diuji
filename = "data/raw/case_030.txt"

# Baca file
with open(os.path.join(filename), 'r', encoding='utf-8') as f:
    text = f.read()
    metadata = extract_metadata(text)
    metadata['case_id'] = "case_001"
    metadata['text_full'] = text

# Simpan ke DataFrame (1 baris saja)
df = pd.DataFrame([metadata])
df
# Out:
#                  nomor_perkara              nama_terdakwa     pekerjaan  \
# 0  111/pid.sus-tpk/2024/pn sby  [aniningsih binti riyadi]  [wiraswasta]
#
#   tindak pidana                                              pasal  \
# 0       korupsi  pasal 2 ayat (1) jo. pasal 18 uu r.i. nomor 31...
#
#       penuntut_umum   tanggal_putusan  \
# 0  tidak disebutkan  24 desember 2024
#
#                                         amar_putusan  \
# 0  menyatakan terdakwa aniningsih binti riyadi te...
#
#                               ringkasan_barang_bukti   case_id  \
# 0  Barang bukti berupa 1 (satu) bundel asli data ...  case_001
#
#                                            text_full
# 0   putusan nomor 111/pid.sus-tpk/2024/pn sby dem...

# %%
import pandas as pd
import os

# Folder input
input_dir = "data/raw"

# List untuk menampung metadata semua file
all_data = []

# Loop semua file .txt
for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):
        file_path = os.path.join(input_dir, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
            metadata = extract_metadata(text)
            metadata['case_id'] = os.path.splitext(filename)[0]
            metadata['text_full'] = text
            all_data.append(metadata)

# Buat DataFrame dari semua metadata
df = pd.DataFrame(all_data)
# Hitung length (jumlah kata)
df["length_text_full"] = df["text_full"].astype(str).apply(lambda x: len(x.split()))

# Tampilkan DataFrame
print(df)
# Out:
#                   nomor_perkara  \
# 0   140/pid.sus-tpk/2024/pn sby
# 1    86/pid.sus-tpk/2024/pn sby
# 2     3/pid.sus-tpk/2025/pn sby
# 3     9/pid.sus-tpk/2025/pn sby
# 4    42/pid.sus-tpk/2024/pn sby
# 5   140/pid.sus-tpk/2024/pn sby
# 6    42/pid.sus-tpk/2024/pn sby
# 7    65/pid.sus-tpk/2024/pn sby
# 8   107/pid.sus-tpk/2024/pn sby
# 9   136/pid.sus-tpk/2024/pn sby
# 10  109/pid.sus-tpk/2024/pn sby
# 11   92/pid.sus-tpk/2024/pn sby
# 12    8/pid.sus-tpk/2025/pn sby
# 13   83/pid.sus-tpk/2024/pn sby
# 14   12/pid.sus-tpk/2025/pn sby
# 15   14/pid.sus-tpk/2025/pn sby
# 16   82/pid.sus-tpk/2024/pn sby
# 17   72/pid.sus-tpk/2024/pn sby
# 18   99/pid.sus-tpk/2024/pn sby
# 19   65/pid.sus-tpk/2024/pn sby
# 20   15/pid.sus-tpk/2025/pn sby
# 21  113/pid.sus-tpk/2024/pn sby
# 22   87/pid.sus-tpk/2024/pn sby
# 23    2/pid.sus-tpk/2025/pn sby
# 24   26/pid.sus-tpk/2025/pn sby
# 25   90/pid.sus-tpk/2024/pn sby
# 26  111/pid.sus-tpk/2024/pn sby
# 27   71/pid.sus-tpk/2024/pn sby
# 28    7/pid.sus-tpk/2025/pn sby
# 29    5/pid.sus-tpk/2025/pn sby
#
#                                         nama_terdakwa  \
# 0                                           [suyanto]
# 1                                 [sujarwo bin jimin]
# 2                               [ir. budi noviantoro]
# 3               [syafa’atul hidayah, indra kusbianto]
# 4   [puput tantriana sari;, hasan aminuddin;, pupu...
# 5                                           [suyanto]
# 6   [puput tantriana sari;, hasan aminuddin;, pupu...
# 7              [mustaqim, s.t. bin muslimin hag (alm]
# 8               [sumaiyah alias ummiyeh binti suraji]
# 9         [ahmad septian hardianto, se, bin saekudin]
# 10  [mochamad cholidi alias mohamadcholidi;, mocha...
# 11                                     [ali mahmudi.]
# 12                             [tri angga setyayana;]
# 13                [suharto, s.e.;, irmawati fauziah;]
# 14                            [heny sri setyaningrum]
# 15                   [sofrowi bin h. marhafi (alm.);]
# 16                               [farid riza maulana]
# 17                                 [wasito bin wiji.]
# 18                        [hendra agus wijaya, s.t.;]
# 19             [mustaqim, s.t. bin muslimin hag (alm]
# 20        [mohammad juhar bin h.muhammad nor (alm.);]
# 21  [taufik pria kurniawan alias piko bin mujito;,...
# 22             [ribut gestarini binti soemadi (alm);]
# 23                        [tria natalina, s.e., m.ba]
# 24                            [mashudi,s.sos.,m.si.;]
# 25                                   [safril hidayat]
# 26                          [aniningsih binti riyadi]
# 27                        [ulis dewi purwanti,s.pd.;]
# 28                           [denny kurniawan, s.h.;]
# 29                          [ir. h. tarwi bin wasit;]
#
#                                             pekerjaan tindak pidana  \
# 0      [mantan sekretaris desa ploso tahun 2019-2022]       korupsi
# 1                                        [wiraswasta]       korupsi
# 2   [pensiunan / direktur utama pt inka (persero) ...       korupsi
# 3                                          [sales pt]       korupsi
# 4           [bupati probolinggo periode tahun 2013 s]       korupsi
# 5      [mantan sekretaris desa ploso tahun 2019-2022]       korupsi
# 6           [bupati probolinggo periode tahun 2013 s]       korupsi
# 7                                               [pjs]       korupsi
# 8                       [wiraswata (pengrajin batik)]       korupsi
# 9   [karyawan bumd pt bank jatim cabang pembantu s...       korupsi
# 10  [wiraswasta (mantan direktur operasional ptpn ...       korupsi
# 11             [perangkat desa (sekdes sidohasri kec]       korupsi
# 12                      [karyawan bumd ( bank jatim)]       korupsi
# 13  [direktur pt multi karya citra mandiri, karyaw...       korupsi
# 14  [pegawai negeri sipil dinas perumahan dan kawa...       korupsi
# 15       [kaur keuangan/bendahara desa gunung rancak]       korupsi
# 16            [wiraswasta// sekertaris desa sukodadi]       korupsi
# 17  [kepala desa tebon kecamatan padangan kabupate...       korupsi
# 18                                  [karyawan swasta]       korupsi
# 19                                              [pjs]       korupsi
# 20                        [kepala desa gunung rancak]       korupsi
# 21                                  [karyawan swasta]       korupsi
# 22             [pensiunan pegawai negeri sipil (pns)]       korupsi
# 23  [regional head titan global capital dan komisa...       korupsi
# 24                                      [pns / ppats]       korupsi
# 25       [konsultan pengawas cv lakucipta consulindo]       korupsi
# 26                                       [wiraswasta]       korupsi
# 27  [sekretaris desa kletek kecamatan taman kabupa...       korupsi
# 28                      [karyawan bumd ( bank jatim)]       korupsi
# 29                        [swasta (direktur utama pt]       korupsi
#
#                                                 pasal  \
# 0   pasal 2 ayat (1) jo pasal 18 undang-undang rin...
# 1   pasal 2 ayat (1) jo pasal 18 undang-undang ri ...
# 2   pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 3   pasal 2 jo pasal 18 ayat (1) huruf b undang-un...
# 4   pasal 55 ayat (1) ke 1 kuhp juncto pasal 65 ay...
# 5   pasal 2 ayat (1) jo pasal 18 undang-undang rin...
# 6   pasal 55 ayat (1) ke 1 kuhp juncto pasal 65 ay...
# 7   pasal 2ayat (1) jo. pasal 18 undang-undang nom...
# 8   pasal 2 dan atau pasal 3 undang – undang no. 2...
# 9   pasal 2 ayat (1) jo pasal 18undang-undang repu...
# 10         pasal 18 undang-undang nomor 31 tahun 1999
# 11  pasal 2 ayat (1) jo pasal 18undang-undang repu...
# 12  pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 13  pasal 2 ayat (1) jo.pasal 18 ayat (1) huruf b ...
# 14  pasal 2 ayat (1) jo pasal 18uu ri no. 31 tahun...
# 15           pasal 3 undang-undang nomor31 tahun 1999
# 16  pasal 2 ayat (1) jo. pasal 18 ayat (1) huruf a...
# 17  pasal 2 ayat (1) undang-undang republik indone...
# 18  pasal 2 ayat (1) jo.pasal 18 undang-undang nom...
# 19  pasal 2ayat (1) jo. pasal 18 undang-undang nom...
# 20  pasal 3 undang-undang nomor 31 tahun1999 tenta...
# 21  pasal 2 jo pasal 18 undang-undang ri nomor 31t...
# 22  pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 23  pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 24          pasal 9 undang-undang nomor 31 tahun 1999
# 25  pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 26  pasal 2 ayat (1) jo. pasal 18 uu r.i. nomor 31...
# 27  pasal 11 undang–undang republik indonesia nomo...
# 28  pasal 2 ayat (1) jo. pasal 18 undang-undang no...
# 29  pasal 2 ayat (1) jo. pasal18 ayat (1) huruf b ...
#
#                 penuntut_umum   tanggal_putusan  \
# 0            tidak disebutkan        9 mei 2025
# 1            tidak disebutkan  31 desember 2024
# 2            tidak disebutkan       27 mei 2025
# 3            tidak disebutkan       26 mei 2025
# 4            tidak disebutkan  13 februari 2025
# 5            tidak disebutkan        9 mei 2025
# 6            tidak disebutkan  13 februari 2025
# 7            tidak disebutkan  19 november 2024
# 8     eddie soedradjat, s.h.,   16 januari 2025
# 9           arfan halim, s.h.  27 februari 2025
# 10           tidak disebutkan   5 februari 2025
# 11           tidak disebutkan    6 januari 2025
# 12           tidak disebutkan      12 juni 2025
# 13             tarjono, s.h.,  18 desember 2024
# 14           tidak disebutkan       26 mei 2025
# 15           tidak disebutkan      10 juni 2025
# 16  anton wahyudi, s.h., m.h.   2 desember 2024
# 17    mohamad arifin, sh., mh  16 desember 2024
# 18           tidak disebutkan   23 januari 2025
# 19           tidak disebutkan  19 november 2024
# 20           tidak disebutkan      10 juni 2025
# 21           tidak disebutkan   09 januari 2024
# 22        tidak ada informasi   6 desember 2024
# 23           tidak disebutkan       27 mei 2025
# 24           tidak disebutkan       27 mei 2025
# 25           tidak disebutkan   10 januari 2025
# 26           tidak disebutkan  24 desember 2024
# 27           tidak disebutkan  10 desember 2024
# 28           tidak disebutkan      12 juni 2025
# 29           tidak disebutkan       27 mei 2025
#
#                                          amar_putusan  \
# 0   menyatakan pemeriksaan perkara ini tanpa kehad...
# 1   menyatakan terdakwa sujarwo bin jimin terbukti...
# 2   menyatakan terdakwa ir. budi noviantoro terbuk...
# 3   menyatakan terdakwa 1 syafa’atul hidayah dan t...
# 4   menyatakan terdakwa i puput tantriana sari dan...
# 5   menyatakan pemeriksaan perkara ini tanpa kehad...
# 6   menyatakan terdakwa i puput tantriana sari dan...
# 7   menyatakan terdakwa mustaqim, s.t. bin muslimi...
# 8   menyatakan terdakwa sumaiyah alias ummiyeh bin...
# 9   menyatakan terdakwa ahmad septian hardianto, s...
# 10  menyatakan terdakwa i mochamad cholidi alias m...
# 11  menyatakan terdakwa ali mahmudi dengan identit...
# 12  menyatakan terdakwa tri angga setyayana, tidak...
# 13  menyatakan terdakwa i suharto, s.e. dan terdak...
# 14  menyatakan terdakwa heny sri setyaningrum ters...
# 15  menyatakan terdakwa sofrowi bin h. marhafi (al...
# 16  menyatakan terdakwa farid riza maulana tersebu...
# 17  menyatakan terdakwa wasito bin wijitersebut di...
# 18  menyatakan terdakwa hendra agus wijaya, s.t. t...
# 19  menyatakan terdakwa mustaqim, s.t. bin muslimi...
# 20  menyatakan terdakwa mohammad juhar bin h. muha...
# 21  menyatakan terdakwa i taufik pria kurniawan al...
# 22  menyatakan terdakwa ribut gestarini binti soem...
# 23  menyatakan terdakwa tria natalina, s.e., m.ba ...
# 24  menyatakan terdakwa mashudi,s.sos.,m.si. tidak...
# 25  menyatakan terdakwa safril hidayat tidak terbu...
# 26  menyatakan terdakwa aniningsih binti riyadi te...
# 27  menyatakan terdakwa ulis dewi purwanti,s.pd. t...
# 28  menyatakan terdakwa denny kurniawan, s.h., tid...
# 29  menyatakan terdakwa ir. h. tarwi bin wasit ter...
#
#                                ringkasan_barang_bukti   case_id  \
# 0   Barang bukti berupa 1 (satu) lembar surat pern...  case_022
# 1   Barang bukti berupa 1 (satu) bendel fc surat k...  case_021
# 2   Barang bukti berupa barang bukti (dalam daftar...  case_018
# 3   Barang bukti berupa uang tunai sejumlah rp 15....  case_003
# 4   Barang bukti berupa 35-120 tahun 2013 tentang ...  case_004
# 5   Barang bukti berupa 1 (satu) lembar surat pern...  case_026
# 6   Barang bukti berupa 35-120 tahun 2013 tentang ...  case_010
# 7   Barang bukti berupa 1 (satu) lembar asli bukti...  case_017
# 8   Barang bukti berupa 1 (satu) bendel foto copy ...  case_024
# 9   Barang bukti berupa 1 (satu) lembar asli berit...  case_001
# 10  Barang bukti berupa 1 (satu) buah map meiko ab...  case_020
# 11  Barang bukti berupa 1 (satu) lembar asli pilot...  case_023
# 12  Barang bukti berupa 2 (dua) lembar perjanjian ...  case_007
# 13  Barang bukti berupa 1 (satu) bundel fotokopi p...  case_002
# 14  Barang bukti berupa uang tunai sebesar rp. 8.0...  case_005
# 15  Barang bukti berupa 1 (satu) bundel asli perat...  case_025
# 16  Barang bukti berupa 1 (satu) buku tabungan bri...  case_019
# 17  Barang bukti berupa .1 (satu) bendel dokumen f...  case_016
# 18  Barang bukti berupa 1 (satu) bundel pembiayaan...  case_014
# 19  Barang bukti berupa 1 (satu) lembar asli bukti...  case_006
# 20  Barang bukti berupa 1 (satu) bundel asli perat...  case_009
# 21  Barang bukti berupa 1 (satu) buah buku rekenin...  case_011
# 22  Barang bukti berupa . 1 (satu) bendel laporan ...  case_029
# 23  Barang bukti berupa barang bukti (dalam daftar...  case_027
# 24  Barang bukti berupa 2 (dua) lembar foto copy d...  case_015
# 25  Barang bukti berupa dokumen fotocopy dokumen p...  case_028
# 26  Barang bukti berupa 1 (satu) bundel asli data ...  case_030
# 27  Barang bukti berupa h.a.2. 1)1 (satu) lembar a...  case_013
# 28  Barang bukti berupa 2 (dua) lembar perjanjian ...  case_008
# 29  Barang bukti berupa rekening koran pt wahyu ti...  case_012
#
#                                             text_full  length_text_full
# 0    putusan nomor 140/pid.sus-tpk/2024/pn sby dem...             85373
# 1    putusan nomor 86/pid.sus-tpk/2024/pn sby demi...             68361
# 2    putusan nomor 3/pid.sus-tpk/2025/pn sby demi ...            120124
# 3    putusan nomor 9/pid.sus-tpk/2025/pn sby demi ...            210620
# 4    putusan nomor: 42/pid.sus-tpk/2024/pn sby dem...            796006
# 5    putusan nomor 140/pid.sus-tpk/2024/pn sby dem...             85373
# 6    putusan nomor: 42/pid.sus-tpk/2024/pn sby dem...            796006
# 7    putusan nomor 65/pid.sus -tpk/ 2024/pn sby de...             66738
# 8    putusan nomor 107/pid.sus-tpk/2024/pn sby dem...             48940
# 9    putusan nomor 136/pid.sus-tpk/2024/pn sby dem...             36248
# 10   putusan nomor 109/pid.sus-tpk/2024/pn sby dem...            240490
# 11   putusan nomor 92/pid.sus-tpk/2024/pn sby demi...             53618
# 12   putusannomor: 8/pid.sus-tpk/2025/pn sby demi ...             63861
# 13   putusan nomor 83/pid.sus-tpk/2024/pn sby demi...             60740
# 14   putusan nomor 12/pid.sus-tpk/2025/pn sby demi...             93342
# 15   putusan nomor 14/pid.sus-tpk/2025/pn sby demi...             57725
# 16   putusan nomor 82/pid.sus-tpk/2024/pn sby demi...             71922
# 17   putusan nomor 72/pid.sus-tpk/2024/pn sby demi...             38631
# 18   putusan nomor 99/pid.sus-tpk/2024/pn sby demi...            172141
# 19   putusan nomor 65/pid.sus -tpk/ 2024/pn sby de...             66738
# 20   putusan nomor 15/pid.sus-tpk/2025/pn sby demi...             57156
# 21   putusannomor: 113/pid.sus-tpk/2024/pn sby dem...             39979
# 22   putusan nomor : 87/pid.sus-tpk/2024/pn sby de...            125700
# 23   putusan nomor 2/pid.sus-tpk/2025/pn sby demi ...            125427
# 24   putusan nomor 26/pid.sus-tpk/2025/pn sby demi...             77777
# 25   putusan nomor 90/pid.sus -tpk/ 2024/pn sby de...             67354
# 26   putusan nomor 111/pid.sus-tpk/2024/pn sby dem...             52143
# 27   putusan nomor 71/pid.sus-tpk/2024/pn sby demi...             58047
# 28   putusannomor: 7/pid.sus-tpk/2025/pn sby demi ...             65549
# 29   putusan nomor 5/pid.sus-tpk/2025/pn sby demi ...            148926

# %%
df.to_json("data/processed/cases.json", orient='records', indent=2, force_ascii=False)
